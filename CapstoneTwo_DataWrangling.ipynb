# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
train = pd.read_csv('../input/train.csv')
weather = pd.read_csv('../input/weather.csv')
train['Date'] = pd.to_datetime(train['Date'])
weather['Date'] = pd.to_datetime(weather['Date'])
df_train = pd.merge(train, weather, on='Date', how='inner')
df_train.head()
# Out:
#         Date                                            Address  \
# 0 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 3 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 4 2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 3          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 4          CULEX RESTUANS     62    N MANDELL AVE  T007
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21012 entries, 0 to 21011
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    21012 non-null  datetime64[ns]
#  1   Address                 21012 non-null  object
#  2   Species                 21012 non-null  object
#  3   Block                   21012 non-null  int64
#  4   Street                  21012 non-null  object
#  5   Trap                    21012 non-null  object
#  6   AddressNumberAndStreet  21012 non-null  object
#  7   Latitude                21012 non-null  float64
#  8   Longitude               21012 non-null  float64
#  9   AddressAccuracy         21012 non-null  int64
#  10  NumMosquitos            21012 non-null  int64
#  11  WnvPresent              21012 non-null  int64
#  12  Station                 21012 non-null  int64
#  13  Tmax                    21012 non-null  int64
# ...

# %%
df_train.describe()
# Out:
#               Block      Latitude     Longitude  AddressAccuracy  \
# count  21012.000000  21012.000000  21012.000000     21012.000000
# mean      35.687797     41.841139    -87.699908         7.819532
# std       24.338889      0.112739      0.096512         1.452886
# min       10.000000     41.644612    -87.930995         3.000000
# 25%       12.000000     41.732984    -87.760070         8.000000
# 50%       33.000000     41.846283    -87.694991         8.000000
# 75%       52.000000     41.954690    -87.627796         9.000000
# max       98.000000     42.017430    -87.531635         9.000000
#
#        NumMosquitos    WnvPresent       Station          Tmax          Tmin  \
# count  21012.000000  21012.000000  21012.000000  21012.000000  21012.000000
# mean      12.853512      0.052446      1.500000     81.917095     63.647202
# std       16.133432      0.222930      0.500012      8.290251      7.593949
# ...

# %%
null_values = df_train.isnull().any()
print(null_values)
# Out:
# Date                      False
# Address                   False
# Species                   False
# Block                     False
# Street                    False
# Trap                      False
# AddressNumberAndStreet    False
# Latitude                  False
# Longitude                 False
# AddressAccuracy           False
# NumMosquitos              False
# WnvPresent                False
# Station                   False
# Tmax                      False
# Tmin                      False
# Tavg                      False
# Depart                    False
# DewPoint                  False
# WetBulb                   False
# Heat                      False
# Cool                      False
# Sunrise                   False
# Sunset                    False
# CodeSum                   False
# Depth                     False
# Water1                    False
# SnowFall                  False
# PrecipTotal               False
# StnPressure               False
# ...

# %%
nan_values = df_train.isna().any()
print(nan_values)
# Out:
# Date                      False
# Address                   False
# Species                   False
# Block                     False
# Street                    False
# Trap                      False
# AddressNumberAndStreet    False
# Latitude                  False
# Longitude                 False
# AddressAccuracy           False
# NumMosquitos              False
# WnvPresent                False
# Station                   False
# Tmax                      False
# Tmin                      False
# Tavg                      False
# Depart                    False
# DewPoint                  False
# WetBulb                   False
# Heat                      False
# Cool                      False
# Sunrise                   False
# Sunset                    False
# CodeSum                   False
# Depth                     False
# Water1                    False
# SnowFall                  False
# PrecipTotal               False
# StnPressure               False
# ...

# %%
duplicates = df_train.duplicated().any()
print("Duplicate values in any column:", duplicates)
# Out:
# Duplicate values in any column: True

# %%
duplicate_columns = df_train.columns[df_train.apply(lambda x: x.duplicated()).any()].tolist()
print(duplicate_columns)
# Out:
# ['Date', 'Address', 'Species', 'Block', 'Street', 'Trap', 'AddressNumberAndStreet', 'Latitude', 'Longitude', 'AddressAccuracy', 'NumMosquitos', 'WnvPresent', 'Station', 'Tmax', 'Tmin', 'Tavg', 'Depart', 'DewPoint', 'WetBulb', 'Heat', 'Cool', 'Sunrise', 'Sunset', 'CodeSum', 'Depth', 'Water1', 'SnowFall', 'PrecipTotal', 'StnPressure', 'SeaLevel', 'ResultSpeed', 'ResultDir', 'AvgSpeed']

# %%
df_train.head()
# Out:
#         Date                                            Address  \
# 0 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 1 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 3 2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 4 2007-05-29  6200 North Mandell Avenue, Chicago, IL 60646, USA
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 1  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
# 2          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 3          CULEX RESTUANS     41   N OAK PARK AVE  T002
# 4          CULEX RESTUANS     62    N MANDELL AVE  T007
#
#               AddressNumberAndStreet   Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# 1  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991                9
# ...

# %%
df_train.columns
# Out:
# Index(['Date', 'Address', 'Species', 'Block', 'Street', 'Trap',
#        'AddressNumberAndStreet', 'Latitude', 'Longitude', 'AddressAccuracy',
#        'NumMosquitos', 'WnvPresent', 'Station', 'Tmax', 'Tmin', 'Tavg',
#        'Depart', 'DewPoint', 'WetBulb', 'Heat', 'Cool', 'Sunrise', 'Sunset',
#        'CodeSum', 'Depth', 'Water1', 'SnowFall', 'PrecipTotal', 'StnPressure',
#        'SeaLevel', 'ResultSpeed', 'ResultDir', 'AvgSpeed'],
#       dtype='object')

# %%
df_train=df_train[['Date', 'Species', 'Trap','Latitude', 'Longitude', 'NumMosquitos', 'WnvPresent', 'Tmax', 'Tmin', 'Tavg',
 'DewPoint', 'WetBulb', 'Heat', 'Cool', 'Sunrise', 'Sunset', 'Depth', 'SnowFall', 'PrecipTotal', 'StnPressure',
       'SeaLevel', 'ResultSpeed', 'ResultDir', 'AvgSpeed' ]]
df_train
# Out:
#             Date                 Species  Trap   Latitude  Longitude  \
# 0     2007-05-29  CULEX PIPIENS/RESTUANS  T002  41.954690 -87.800991
# 1     2007-05-29  CULEX PIPIENS/RESTUANS  T002  41.954690 -87.800991
# 2     2007-05-29          CULEX RESTUANS  T002  41.954690 -87.800991
# 3     2007-05-29          CULEX RESTUANS  T002  41.954690 -87.800991
# 4     2007-05-29          CULEX RESTUANS  T007  41.994991 -87.769279
# ...          ...                     ...   ...        ...        ...
# 21007 2013-09-26  CULEX PIPIENS/RESTUANS  T232  41.912563 -87.668055
# 21008 2013-09-26  CULEX PIPIENS/RESTUANS  T233  42.009876 -87.807277
# 21009 2013-09-26  CULEX PIPIENS/RESTUANS  T233  42.009876 -87.807277
# 21010 2013-09-26  CULEX PIPIENS/RESTUANS  T235  41.776428 -87.627096
# 21011 2013-09-26  CULEX PIPIENS/RESTUANS  T235  41.776428 -87.627096
#
#        NumMosquitos  WnvPresent  Tmax  Tmin Tavg  ...  Sunrise Sunset Depth  \
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21012 entries, 0 to 21011
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          21012 non-null  datetime64[ns]
#  1   Species       21012 non-null  object
#  2   Trap          21012 non-null  object
#  3   Latitude      21012 non-null  float64
#  4   Longitude     21012 non-null  float64
#  5   NumMosquitos  21012 non-null  int64
#  6   WnvPresent    21012 non-null  int64
#  7   Tmax          21012 non-null  int64
#  8   Tmin          21012 non-null  int64
#  9   Tavg          21012 non-null  object
#  10  DewPoint      21012 non-null  int64
#  11  WetBulb       21012 non-null  object
#  12  Heat          21012 non-null  object
#  13  Cool          21012 non-null  object
#  14  Sunrise       21012 non-null  object
#  15  Sunset        21012 non-null  object
#  16  Depth         21012 non-null  object
#  17  SnowFall      21012 non-null  object
# ...
